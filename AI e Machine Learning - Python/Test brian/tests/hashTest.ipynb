# %%
import hashlib
testo=open('/content/brian.txt','r')
lol=testo.readline()
print(lol)
print("\n")
hashish=hashlib.sha256(lol.encode('utf-8')).hexdigest()
print(hashish)
# Out:
# hola mundo
#
#
# 0b894166d3336435c800bea36ff21b29eaa801a52f584c006c49289a0dcf6e2f
