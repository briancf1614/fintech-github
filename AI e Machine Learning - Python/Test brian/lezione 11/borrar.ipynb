# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url="/content/drive/MyDrive/appunti_fintech/AI e Machine Learning - Python/Test brian/lezione 11/dati_prenotazioni.csv"
df=pd.read_csv(url)
display(df)
display(df.iloc[[5], ["prenotazioni"]])
# Out:
#     Unnamed: 0  prenotazioni  pizze  eventi bar
# 0            0            50     56           1
# 1            1            83     95           0
# 2            2            71     80           0
# 3            3           109    124           0
# 4            4            10     40           1
# ..         ...           ...    ...         ...
# 95          95            71     99           0
# 96          96            76     81           0
# 97          97            89    101           0
# 98          98            69    101           0
# 99          99            53     59           1
#
# [100 rows x 4 columns]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-403a98af52f7> in <module>
#       2 df=pd.read_csv(url)
#       3 display(df)
# ----> 4 display(df.iloc[[5], ["prenotazioni"]])
#
# ...
