# %%
# ==================================================
# in questo caso se voglio fare operazioni matematiche faccio
# ==================================================

n1=3**2
print(n1)
n2=5**3
print(n2)

print("se voglio fare il resto di una divisione mi basta solo fare....")

resto=17%2
print(resto,"=",type(resto))
# Out:
# 9
# 125
